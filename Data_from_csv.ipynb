# %%
import numpy as numpy
import pandas as pd
from pandas.io.json import json_normalize

import json
from pprint import pprint

import os

# %%
pwd
# Out:
# '/Users/zacklarsen/Dropbox (Inference Analytics)/Inference Analytics Team Folder/Zack Work'

# %%
ls
# Out:
# 1. O'Reilly Training.ipynb
# 2. O'Reilly Generate.ipynb
# 3. O'Reilly Generate from image.ipynb
# ALL3.ipynb
# Adeel Qureshi Assessor.ipynb
# Airbnb Analytics.ipynb
# AirbnbChicago.csv
# AirbnbLA.csv
# AirbnbNYC.csv
# AirbnbOakland.csv
# AirbnbSF.csv
# AirbnbSanDiego.csv
# Ames_9_21_2017_backup.ipynb
# Austin Time.ipynb
# CSC 529 Final.ipynb
# CSC 575 HW #2.ipynb
# California.png
# Cap Rate or Gross Rent Multiplier to Estimate Property Value?.pdf
# CountDF.csv
# Exploratory NLP Online Retail.ipynb
# Exploratory- CA.txt.ipynb
# Exploratory-Rental Crawl Sample.ipynb
# Exploratory-Rental Crawl Sample_for_Austin.ipynb
# Exploratory.R
# FirstAMListing.ipynb
# GoogleNews-vectors-negative300.bin
# IA.png
# Important features.docx
# King Country.twb
# King County House Sales Kaggle.ipynb
# LA_Crime.csv
# Lifetimes.ipynb
# Markezafile assessment.docx
# Notes.docx
# OR.csv
# Online Retail.csv
# OnlineRetailNLP.ipynb
# README.md
# Real Estate Data Services.pdf
# RentCrawl Modelling.ipynb
# ...

# %%
downloadphpconverttoexcel

# %%
with open('downloadphpconverttoexcel.json') as data_file:    
    data = json.load(data_file)

pprint(data)
# Out:
# {'Data': [{'AccountID': '450758035848538255',
#            'CannedMessageID': '572574913270021263',
#            'ChatID': '447842000754010922',
#            'ChatMessageID': '3720747978566263878',
#            'Created': '2017-04-11T22:40:30.057Z',
#            'Deleted': None,
#            'HasAutoTranslationError': None,
#            'Hidden': None,
#            'LanguageCode': 'en-US',
#            'MessageKey': None,
#            'Name': 'Rick',
#            'OriginalMessageID': None,
#            'PersonID': '3402939147751915780',
#            'PersonType': 0,
#            'SearchName': 'Rick',
#            'SearchText': 'Hello, my name is Rick, how may I help you? ',
#            'SystemMessage': None,
#            'Text': '<font size="2" face="Verdana"></font>Hello, my name is '
#                    'Rick, how may I help you? ',
#            'VisitorFacing': None},
#           {'AccountID': '450758035848538255',
#            'CannedMessageID': None,
# ...

# %%
data = data['Data']

# %%
data["maps"][0]["id"]
data["masks"]["id"]
data["om_points"]

# %%
DF1 = json_normalize(data)

# %%
DF1.head(10)
# Out:
#             AccountID     CannedMessageID              ChatID  \
# 0  450758035848538255  572574913270021263  447842000754010922
# 1  450758035848538255                None  447842000754010922
# 2  450758035848538255                None  447842000754010922
# 3  450758035848538255                None  447842000754010922
# 4  450758035848538255                None  447842000754010922
# 5  450758035848538255                None  447842000754010922
# 6  450758035848538255                None  447842000754010922
# 7  450758035848538255                None  447842000754010922
# 8  450758035848538255  667812436011485266  447842000754010922
# 9  450758035848538255                None  447842000754010922
#
#          ChatMessageID                   Created Deleted  \
# 0  3720747978566263878  2017-04-11T22:40:30.057Z    None
# 1   436031893645829557  2017-04-11T22:41:31.473Z    None
# 2   977570008398613571  2017-04-11T22:41:37.903Z    None
# ...

# %%
DF1.to_csv('Data_from_json.csv')
